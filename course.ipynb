# %% [markdown]
# # 1. Dependencies

# %%
# !pip install stable-baselines3[extra]
# Out:
# Collecting stable-baselines3[extra]
#   Downloading stable_baselines3-1.1.0-py3-none-any.whl (172 kB)
#      |████████████████████████████████| 172 kB 861 kB/s eta 0:00:01
# Collecting matplotlib
#   Downloading matplotlib-3.4.2-cp38-cp38-manylinux1_x86_64.whl (10.3 MB)
#      |████████████████████████████████| 10.3 MB 1.7 MB/s eta 0:00:01    |███████████▊                    | 3.8 MB 698 kB/s eta 0:00:10
# Collecting cloudpickle
#   Downloading cloudpickle-1.6.0-py3-none-any.whl (23 kB)
# Collecting torch>=1.4.0
#   Downloading torch-1.9.0-cp38-cp38-manylinux1_x86_64.whl (831.4 MB)
#      |████████████████████████████████| 831.4 MB 36 kB/s  eta 0:00:01     |█████████▍                      | 243.1 MB 324 kB/s eta 0:30:11
# Collecting gym>=0.17
#   Downloading gym-0.18.3.tar.gz (1.6 MB)
#      |████████████████████████████████| 1.6 MB 1.3 MB/s eta 0:00:01
# Requirement already satisfied: numpy in /home/uruk380/.local/lib/python3.8/site-packages (from stable-baselines3[extra]) (1.19.5)
# Collecting pandas
#   Downloading pandas-1.3.0-cp38-cp38-manylinux_2_5_x86_64.manylinux1_x86_64.whl (10.6 MB)
#      |████████████████████████████████| 10.6 MB 1.5 MB/s eta 0:00:01
# Collecting psutil
#   Downloading psutil-5.8.0-cp38-cp38-manylinux2010_x86_64.whl (296 kB)
#      |████████████████████████████████| 296 kB 1.1 MB/s eta 0:00:01
# Collecting opencv-python
#   Downloading opencv_python-4.5.3.56-cp38-cp38-manylinux2014_x86_64.whl (49.9 MB)
#      |████████████████████████████████| 49.9 MB 277 kB/s eta 0:00:01
# Collecting atari-py~=0.2.0
#   Downloading atari_py-0.2.9-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (2.8 MB)
#      |████████████████████████████████| 2.8 MB 1.2 MB/s eta 0:00:01
# Requirement already satisfied: tensorboard>=2.2.0 in /home/uruk380/.local/lib/python3.8/site-packages (from stable-baselines3[extra]) (2.5.0)
# Collecting pillow
#   Downloading Pillow-8.3.1-cp38-cp38-manylinux_2_5_x86_64.manylinux1_x86_64.whl (3.0 MB)
#      |████████████████████████████████| 3.0 MB 1.5 MB/s eta 0:00:01
# Requirement already satisfied: six in /home/uruk380/.local/lib/python3.8/site-packages (from atari-py~=0.2.0->stable-baselines3[extra]) (1.15.0)
# Collecting scipy
#   Downloading scipy-1.7.0-cp38-cp38-manylinux_2_5_x86_64.manylinux1_x86_64.whl (28.4 MB)
#      |████████████████████████████████| 28.4 MB 995 kB/s eta 0:00:01
# Collecting pyglet<=1.5.15,>=1.4.0
#   Downloading pyglet-1.5.15-py3-none-any.whl (1.1 MB)
#      |████████████████████████████████| 1.1 MB 1.1 MB/s eta 0:00:01
# Collecting pillow
#   Downloading Pillow-8.2.0-cp38-cp38-manylinux1_x86_64.whl (3.0 MB)
#      |████████████████████████████████| 3.0 MB 1.1 MB/s eta 0:00:01
# Requirement already satisfied: google-auth-oauthlib<0.5,>=0.4.1 in /home/uruk380/.local/lib/python3.8/site-packages (from tensorboard>=2.2.0->stable-baselines3[extra]) (0.4.4)
# Requirement already satisfied: absl-py>=0.4 in /home/uruk380/.local/lib/python3.8/site-packages (from tensorboard>=2.2.0->stable-baselines3[extra]) (0.12.0)
# Collecting requests<3,>=2.21.0
#   Downloading requests-2.26.0-py2.py3-none-any.whl (62 kB)
#      |████████████████████████████████| 62 kB 872 kB/s eta 0:00:01
# Collecting markdown>=2.6.8
#   Downloading Markdown-3.3.4-py3-none-any.whl (97 kB)
#      |████████████████████████████████| 97 kB 1.4 MB/s eta 0:00:01
# Requirement already satisfied: tensorboard-data-server<0.7.0,>=0.6.0 in /home/uruk380/.local/lib/python3.8/site-packages (from tensorboard>=2.2.0->stable-baselines3[extra]) (0.6.1)
# Requirement already satisfied: grpcio>=1.24.3 in /home/uruk380/.local/lib/python3.8/site-packages (from tensorboard>=2.2.0->stable-baselines3[extra]) (1.34.1)
# Requirement already satisfied: werkzeug>=0.11.15 in /home/uruk380/.local/lib/python3.8/site-packages (from tensorboard>=2.2.0->stable-baselines3[extra]) (2.0.1)
# Requirement already satisfied: setuptools>=41.0.0 in /home/uruk380/anaconda3/envs/Reinforcement_Learning_YT_course/lib/python3.8/site-packages (from tensorboard>=2.2.0->stable-baselines3[extra]) (52.0.0.post20210125)
# Requirement already satisfied: tensorboard-plugin-wit>=1.6.0 in /home/uruk380/.local/lib/python3.8/site-packages (from tensorboard>=2.2.0->stable-baselines3[extra]) (1.8.0)
# Requirement already satisfied: wheel>=0.26 in /home/uruk380/.local/lib/python3.8/site-packages (from tensorboard>=2.2.0->stable-baselines3[extra]) (0.36.2)
# Requirement already satisfied: google-auth<2,>=1.6.3 in /home/uruk380/.local/lib/python3.8/site-packages (from tensorboard>=2.2.0->stable-baselines3[extra]) (1.32.1)
# Requirement already satisfied: protobuf>=3.6.0 in /home/uruk380/.local/lib/python3.8/site-packages (from tensorboard>=2.2.0->stable-baselines3[extra]) (3.17.1)
# Requirement already satisfied: rsa<5,>=3.1.4 in /home/uruk380/.local/lib/python3.8/site-packages (from google-auth<2,>=1.6.3->tensorboard>=2.2.0->stable-baselines3[extra]) (4.7.2)
# Requirement already satisfied: cachetools<5.0,>=2.0.0 in /home/uruk380/.local/lib/python3.8/site-packages (from google-auth<2,>=1.6.3->tensorboard>=2.2.0->stable-baselines3[extra]) (4.2.2)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /home/uruk380/.local/lib/python3.8/site-packages (from google-auth<2,>=1.6.3->tensorboard>=2.2.0->stable-baselines3[extra]) (0.2.8)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /home/uruk380/.local/lib/python3.8/site-packages (from google-auth-oauthlib<0.5,>=0.4.1->tensorboard>=2.2.0->stable-baselines3[extra]) (1.3.0)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in /home/uruk380/.local/lib/python3.8/site-packages (from pyasn1-modules>=0.2.1->google-auth<2,>=1.6.3->tensorboard>=2.2.0->stable-baselines3[extra]) (0.4.8)
# Collecting urllib3<1.27,>=1.21.1
#   Downloading urllib3-1.26.6-py2.py3-none-any.whl (138 kB)
#      |████████████████████████████████| 138 kB 937 kB/s eta 0:00:01
# Collecting charset-normalizer~=2.0.0
#   Downloading charset_normalizer-2.0.1-py3-none-any.whl (35 kB)
# Requirement already satisfied: certifi>=2017.4.17 in /home/uruk380/anaconda3/envs/Reinforcement_Learning_YT_course/lib/python3.8/site-packages (from requests<3,>=2.21.0->tensorboard>=2.2.0->stable-baselines3[extra]) (2021.5.30)
# Collecting idna<4,>=2.5
#   Downloading idna-3.2-py3-none-any.whl (59 kB)
#      |████████████████████████████████| 59 kB 1.2 MB/s eta 0:00:01
# Collecting oauthlib>=3.0.0
#   Using cached oauthlib-3.1.1-py2.py3-none-any.whl (146 kB)
# Requirement already satisfied: typing-extensions in /home/uruk380/.local/lib/python3.8/site-packages (from torch>=1.4.0->stable-baselines3[extra]) (3.7.4.3)
# Requirement already satisfied: pyparsing>=2.2.1 in /home/uruk380/anaconda3/envs/Reinforcement_Learning_YT_course/lib/python3.8/site-packages (from matplotlib->stable-baselines3[extra]) (2.4.7)
# Collecting kiwisolver>=1.0.1
#   Downloading kiwisolver-1.3.1-cp38-cp38-manylinux1_x86_64.whl (1.2 MB)
#      |████████████████████████████████| 1.2 MB 977 kB/s eta 0:00:01
# Requirement already satisfied: python-dateutil>=2.7 in /home/uruk380/anaconda3/envs/Reinforcement_Learning_YT_course/lib/python3.8/site-packages (from matplotlib->stable-baselines3[extra]) (2.8.1)
# Collecting cycler>=0.10
#   Downloading cycler-0.10.0-py2.py3-none-any.whl (6.5 kB)
# Collecting pytz>=2017.3
#   Downloading pytz-2021.1-py2.py3-none-any.whl (510 kB)
#      |████████████████████████████████| 510 kB 1.3 MB/s eta 0:00:01
# Building wheels for collected packages: gym
# done
#   Created wheel for gym: filename=gym-0.18.3-py3-none-any.whl size=1657516 sha256=fd727b3eddee124a453bd0b08bcf283d93e82de922b4121cd7048a3ef1ecb12f
#   Stored in directory: /home/uruk380/.cache/pip/wheels/b3/03/54/9141c232861b89be935b37bdde0ea5ab472f5e18fc20623aed
# Successfully built gym
# Installing collected packages: urllib3, idna, charset-normalizer, requests, oauthlib, scipy, pytz, pyglet, pillow, kiwisolver, cycler, cloudpickle, torch, pandas, matplotlib, markdown, gym, stable-baselines3, psutil, opencv-python, atari-py
# Successfully installed atari-py-0.2.9 charset-normalizer-2.0.1 cloudpickle-1.6.0 cycler-0.10.0 gym-0.18.3 idna-3.2 kiwisolver-1.3.1 markdown-3.3.4 matplotlib-3.4.2 oauthlib-3.1.1 opencv-python-4.5.3.56 pandas-1.3.0 pillow-8.2.0 psutil-5.8.0 pyglet-1.5.15 pytz-2021.1 requests-2.26.0 scipy-1.7.0 stable-baselines3-1.1.0 torch-1.9.0 urllib3-1.26.6

# %%
import os
import gym # OpenAI gym
from stable_baselines3 import PPO # on fait le choix de prendre cet algorithme parmi (A2C,ACER,DQN,....)
from stable_baselines3.common.vec_env import DummyVecEnv # huge boost (use in the breakdown game)
from stable_baselines3.common.evaluation import evaluate_policy # easier to test our model

# %% [markdown]
# # 2. Load Environnement

# %%
environnement_name = 'CartPole-v0'
env = gym.make(environnement_name)

# %%
episodes = 5  # we test the cartpole environnement five times
# an episode must be seen as one full game within the environment
# same environments have a fixed episode length
    # CartPole which is 200 frames
    # others are continuous
        # Breakout play until you run out of lives
for episode in range(1,episodes+1):
    state = env.reset() # we have an initial set of observation for the environment
    done = False # is our episode is done ?
    score = 0 # compter

    while not done:
        # allow to view the graphical representation of the environment
        env.render()
        # generate a random action
        action = env.action_space.sample()
        # return the agent's observation (the next observation)
        # n_state = array of the new observation space
        # reward = 1 or 0
        # done = whether or not the episode is done -> if True we go out of the while loop
        # info is a dict
        n_state, reward, done, info = env.step(action)
        # we accumulate and save the total amount of reward
        score += reward
    print('Episode: {} Score: {}'.format(episode,score))
env.close()
# Out:
# Episode: 1 Score: 19.0
# Episode: 2 Score: 31.0
# Episode: 3 Score: 10.0
# Episode: 4 Score: 34.0
# Episode: 5 Score: 67.0

# %%
env.close()

# %%
print(env.reset())
# Out:
# [ 0.04144566 -0.03622807  0.01082143 -0.00254106]

# %%
print(env.action_space)
# if we drop sample we obtain Discrete(2), in fact we can only have 0 or 1 -> our action space
print(env.observation_space)
# we obtain a Box form : (lowbound, upperbound, nb of comma = nb of values in the observation space (env.reset()), type of the numbers
# Out:
# Discrete(2)
# Box(-3.4028234663852886e+38, 3.4028234663852886e+38, (4,), float32)

# %%
env.step(1)
# the length of an episode is a how many step there are
# Out:
# (array([ 0.0407211 ,  0.15873703,  0.0107706 , -0.29179014]), 1.0, False, {})

# %% [markdown]
# ### Env.Functions
# The main environnement fucntions are :
# * env.reset() - reset the environment and obtain initial observations
# * env.render() - visualise the environment
# * env.step() - apply an action to the environment
# * env.close() - close down the render frame

# %% [markdown]
# ### Understanding The Environnement

# %% [markdown]
# https://github.com/openai/gym/blob/master/gym/envs/classic_control/cartpole.py

# %%
env.action_space
# Out:
# Discrete(2)

# %%
# 0 -> push cart to left,
# 1 -> push cart to the right
env.action_space.sample()
# Out:
# 0

# %%
env.observation_space
# Out:
# Box(-3.4028234663852886e+38, 3.4028234663852886e+38, (4,), float32)

# %%
# [cart position, cart velocity, pole angle, pole angular velocity]
env.observation_space.sample()
# Out:
# array([ 3.8455968e+00,  2.7743742e+38, -1.9475874e-01,  2.5730391e+38],
#       dtype=float32)

# %% [markdown]
# # 3. Traning

# %% [markdown]
# stable_baselines focus on
#     Model-Free RL
#         Policy optimization : PPO, Policy Gradient, A2C...
#         Q-learning : DQN
# stable_baselines not focus on
#     Model-Based RL which try to predict the futur state
#         AlphaZero

# %% [markdown]
# There are a number of algorithms available through Stable baselines
# Each algorithms will perform better for certain environments based on action space
#
# Here existing action space :
#     Box
#     Discrete
#     MultiDiscrete
#     MultiBinary
#     Multi Processing

# %%
# becareful we have to create Training directory in which we create Logs directory and Saved Models directory
log_path =  os.path.join('Training','Logs')

# %%
log_path
# Out:
# 'Training/Logs'

# %%
env = gym.make(environnement_name)
# we wrap our en in DummyVecEnv
env = DummyVecEnv([lambda :env])
model = PPO(policy="MlpPolicy",env=env,verbose=1,tensorboard_log=log_path)
# we have to think of an agent's policy as the rule which tells it how to operate in the environnement
# stable baselines 3 has three policy types : MlpPolicy, CnnPolicy and MultiInputPolicy
# Out:
# Using cpu device

# %%
model.learn(total_timesteps=20000)
# Out:
# Logging to Training/Logs/PPO_2
# -----------------------------
# | time/              |      |
# |    fps             | 2686 |
# |    iterations      | 1    |
# |    time_elapsed    | 0    |
# |    total_timesteps | 2048 |
# -----------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1890        |
# |    iterations           | 2           |
# |    time_elapsed         | 2           |
# |    total_timesteps      | 4096        |
# | train/                  |             |
# |    approx_kl            | 0.009471068 |
# |    clip_fraction        | 0.0908      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.567      |
# |    explained_variance   | 0.694       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 22.8        |
# |    n_updates            | 110         |
# |    policy_gradient_loss | -0.00969    |
# |    value_loss           | 72.7        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1712        |
# |    iterations           | 3           |
# |    time_elapsed         | 3           |
# |    total_timesteps      | 6144        |
# | train/                  |             |
# |    approx_kl            | 0.004217758 |
# |    clip_fraction        | 0.0143      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.568      |
# |    explained_variance   | 0.477       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 85.8        |
# |    n_updates            | 120         |
# |    policy_gradient_loss | -0.000822   |
# |    value_loss           | 113         |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 1638         |
# |    iterations           | 4            |
# |    time_elapsed         | 4            |
# |    total_timesteps      | 8192         |
# | train/                  |              |
# |    approx_kl            | 0.0055201426 |
# |    clip_fraction        | 0.051        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.554       |
# |    explained_variance   | 0.659        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 67.3         |
# |    n_updates            | 130          |
# |    policy_gradient_loss | -0.00642     |
# |    value_loss           | 84.3         |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1576        |
# |    iterations           | 5           |
# |    time_elapsed         | 6           |
# |    total_timesteps      | 10240       |
# | train/                  |             |
# |    approx_kl            | 0.002978756 |
# |    clip_fraction        | 0.0182      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.544      |
# |    explained_variance   | 0.517       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 56.6        |
# |    n_updates            | 140         |
# |    policy_gradient_loss | -0.00211    |
# |    value_loss           | 112         |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 1545         |
# |    iterations           | 6            |
# |    time_elapsed         | 7            |
# |    total_timesteps      | 12288        |
# | train/                  |              |
# |    approx_kl            | 0.0044248486 |
# |    clip_fraction        | 0.0295       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.543       |
# |    explained_variance   | 0.633        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 39.4         |
# |    n_updates            | 150          |
# |    policy_gradient_loss | -0.00219     |
# |    value_loss           | 86.9         |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 1520         |
# |    iterations           | 7            |
# |    time_elapsed         | 9            |
# |    total_timesteps      | 14336        |
# | train/                  |              |
# |    approx_kl            | 0.0051746396 |
# |    clip_fraction        | 0.0475       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.541       |
# |    explained_variance   | 0.206        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 127          |
# |    n_updates            | 160          |
# |    policy_gradient_loss | -0.00306     |
# |    value_loss           | 160          |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 1494         |
# |    iterations           | 8            |
# |    time_elapsed         | 10           |
# |    total_timesteps      | 16384        |
# | train/                  |              |
# |    approx_kl            | 0.0036635145 |
# |    clip_fraction        | 0.0379       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.554       |
# |    explained_variance   | 0.0329       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 73.1         |
# |    n_updates            | 170          |
# |    policy_gradient_loss | -0.00322     |
# |    value_loss           | 191          |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 1484         |
# |    iterations           | 9            |
# |    time_elapsed         | 12           |
# |    total_timesteps      | 18432        |
# | train/                  |              |
# |    approx_kl            | 0.0020844932 |
# |    clip_fraction        | 0.0218       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.559       |
# |    explained_variance   | 0.426        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 87.3         |
# |    n_updates            | 180          |
# |    policy_gradient_loss | -0.00284     |
# |    value_loss           | 140          |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1475        |
# |    iterations           | 10          |
# |    time_elapsed         | 13          |
# |    total_timesteps      | 20480       |
# | train/                  |             |
# |    approx_kl            | 0.007864397 |
# |    clip_fraction        | 0.0825      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.554      |
# |    explained_variance   | 0.336       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 26.8        |
# |    n_updates            | 190         |
# |    policy_gradient_loss | -0.00653    |
# |    value_loss           | 134         |
# -----------------------------------------

# %% [markdown]
# # 4. Save and Reload Model

# %%
PPO_Path = os.path.join('Training','Saved Models','PPO_Model_Cartpole')

# %%
model.save(PPO_Path)

# %%
PPO_Path
# Out:
# 'Training/Saved Models/PPO_Model_Cartpole'

# %%
del model

# %%
model.learn(total_timesteps=1000)
# Out:
# Logging to Training/Logs/PPO_3
# -----------------------------
# | time/              |      |
# |    fps             | 2666 |
# |    iterations      | 1    |
# |    time_elapsed    | 0    |
# |    total_timesteps | 2048 |
# -----------------------------

# %%
model=PPO.load(PPO_Path,env=env)

# %% [markdown]
# # 5. Testing and Evaluation

# %% [markdown]
# Evaluation metrics
#
# There are number of metrics available from the models when trained but twore core value taht you should pay attention to.
# rollout/*ep_len_mean*
#     on average how long a particular episode lasted before done
# rollout/*ep_rew_mean*
#     the average reward that the agent accumulated per episode
#
# available with A2C algorithm but
# careful with PPO algorithm we don't have these metrics
#     we evaluate the model itself
#     we evaluate the evaluate policy
#
# Monitoring in Tensorboard
# We are able to review evaluation, time and training metrics from within tensoboard
# In order to do, so we must specify a logging directory when you initialise your model
#
# The PPO model in this case is considered solved if we get on average a score of 200 or higher
# but there is not always this kind of threshold

# %%
 # Evaluation : we use our import located in top of the nb
evaluate_policy(model=model,env=env,n_eval_episodes=10,render=True)
# Out:
# /home/uruk380/anaconda3/envs/Reinforcement_Learning_YT_course/lib/python3.8/site-packages/stable_baselines3/common/evaluation.py:65: UserWarning: Evaluation environment is not wrapped with a ``Monitor`` wrapper. This may result in reporting modified episode lengths and rewards, if other wrappers happen to modify these. Consider wrapping environment first with ``Monitor`` wrapper.
#   warnings.warn(
# (200.0, 0.0)

# %%
env.close()

# %% [markdown]
# Good to know : CartPole Reward
# Reward for CartPOle is calculated as 1 point for every step that the pole remains upright (with a max of 200 steps)
# The max is 200 because CartPole is composed of 200 frames
# If the pole is more than 15 degrees from vertical or the cart moves more than 2.4 units from center the episode ends
# -> there is a margin of error

# %% [markdown]
# # 6. Test Model / Test the agent

# %%
episodes = 5  # we test the cartpole environnement five times
# an episode must be seen as one full game within the environment
# same environments have a fixed episode length
    # CartPole which is 200 frames (length of an episode)
    # others are continuous
        # Breakout play until you run out of lives
for episode in range(1,episodes+1):
    obs = env.reset() # we have an initial set of observation for the environment
    done = False # is our episode is done ?
    score = 0 # compter

    while not done:
        # allow to view the graphical representation of the environment
        env.render()
        # We use our agent here to determine the better action
        action, _ = model.predict(obs)
        # return the agent's observation (the next observation)
        # obs = array of the new observation space
        # reward = 1 or 0
        # done = whether or not the episode is done -> if True we go out of the while loop
        # info is a dict
        obs, reward, done, info = env.step(action)
        # we accumulate and save the total amount of reward
        score += reward
    print('Episode: {} Score: {}'.format(episode,score))
env.close()
# Out:
# Episode: 1 Score: [200.]
# Episode: 2 Score: [200.]
# Episode: 3 Score: [200.]
# Episode: 4 Score: [200.]
# Episode: 5 Score: [200.]

# %%
env.close()

# %%
obs = env.reset()

# %%
obs
# Out:
# array([[-0.04191476, -0.04096119,  0.02818076, -0.0303325 ]],
#       dtype=float32)

# %%
action, _ = model.predict(obs)
# in our case as we do not use recurrent policies model.predict only return the model's action
# it doesn't return the next state which explains "_"

# %%
print(action)
# array[0]  mean the model predict the action 0
print(env.action_space.sample())
# Out:
# [0]
# 0

# %%
# allow us to get the reward
env.step(action)
# array[1,] is a reward of 1
# Out:
# (array([[-0.04273398, -0.2364757 ,  0.02757411,  0.27110687]],
#        dtype=float32),
#  array([1.], dtype=float32),
#  array([False]),
#  [{}])

# %% [markdown]
# # 7. Viewing Logs in Tensorboard

# %%
training_log_path = os.path.join(log_path,'PPO_2')

# %%
# !tensorboard --logdir={training_log_path}
# we need to stop the cell
# Out:
# 2021-07-14 19:05:09.411248: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcudart.so.11.0'; dlerror: libcudart.so.11.0: cannot open shared object file: No such file or directory
# 2021-07-14 19:05:09.411270: I tensorflow/stream_executor/cuda/cudart_stub.cc:29] Ignore above cudart dlerror if you do not have a GPU set up on your machine.
#
# NOTE: Using experimental fast data loading logic. To disable, pass
#     "--load_fast=false" and report issues on GitHub. More details:
#     https://github.com/tensorflow/tensorboard/issues/4784
#
# Serving TensorBoard on localhost; to expose to the network, use a proxy or pass --bind_all
# TensorBoard 2.5.0 at http://localhost:6006/ (Press CTRL+C to quit)
# ^C

# %% [markdown]
# Core metrics to look at :
# 1. Average Reward
# 2. Average Episode length
#
# Training Strategies :
# 1. Train for longer
# 2. Hyperparamater tuning ( useful package optuna)
# 3. Try Different algorithms

# %% [markdown]
# # 8. Adding a callback to the training Stage

# %%
# stop earlier our program before it become unstable, useful to reduce the training time

# %%
from stable_baselines3.common.callbacks import EvalCallback,StopTrainingOnRewardThreshold

# %%
stop_callback = StopTrainingOnRewardThreshold(reward_threshold=200,verbose=1)

# %%
save_path = os.path.join('Training','Saved Models')

# %%
eval_callback = EvalCallback(env,
                             callback_on_new_best=stop_callback,
                             eval_freq=10000,
                             best_model_save_path=save_path,
                             verbose=1)

# %%
model = PPO('MlpPolicy',env,verbose=1,tensorboard_log=log_path)
# Out:
# Using cpu device

# %%
model.learn(total_timesteps=20000,callback=eval_callback)
# Out:
# Logging to Training/Logs/PPO_4
# -----------------------------
# | time/              |      |
# |    fps             | 2624 |
# |    iterations      | 1    |
# |    time_elapsed    | 0    |
# |    total_timesteps | 2048 |
# -----------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 1875       |
# |    iterations           | 2          |
# |    time_elapsed         | 2          |
# |    total_timesteps      | 4096       |
# | train/                  |            |
# |    approx_kl            | 0.00939241 |
# |    clip_fraction        | 0.0867     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.687     |
# |    explained_variance   | 0.00546    |
# |    learning_rate        | 0.0003     |
# |    loss                 | 7.47       |
# |    n_updates            | 10         |
# |    policy_gradient_loss | -0.0121    |
# |    value_loss           | 54.5       |
# ----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1750        |
# |    iterations           | 3           |
# |    time_elapsed         | 3           |
# |    total_timesteps      | 6144        |
# | train/                  |             |
# |    approx_kl            | 0.009518316 |
# |    clip_fraction        | 0.0778      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.666      |
# |    explained_variance   | 0.079       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 12.7        |
# |    n_updates            | 20          |
# |    policy_gradient_loss | -0.0205     |
# |    value_loss           | 34.5        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1708        |
# |    iterations           | 4           |
# |    time_elapsed         | 4           |
# |    total_timesteps      | 8192        |
# | train/                  |             |
# |    approx_kl            | 0.010561533 |
# |    clip_fraction        | 0.11        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.639      |
# |    explained_variance   | 0.271       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 14.9        |
# |    n_updates            | 30          |
# |    policy_gradient_loss | -0.0206     |
# |    value_loss           | 50.8        |
# -----------------------------------------
# Eval num_timesteps=10000, episode_reward=200.00 +/- 0.00
# Episode length: 200.00 +/- 0.00
# -----------------------------------------
# | eval/                   |             |
# |    mean_ep_length       | 200         |
# |    mean_reward          | 200         |
# | time/                   |             |
# |    total timesteps      | 10000       |
# | train/                  |             |
# |    approx_kl            | 0.007952778 |
# |    clip_fraction        | 0.0589      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.617      |
# |    explained_variance   | 0.418       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 34.8        |
# |    n_updates            | 40          |
# |    policy_gradient_loss | -0.0122     |
# |    value_loss           | 63.2        |
# -----------------------------------------
# New best mean reward!
# Stopping training because the mean reward 200.00  is above the threshold 200
# /home/uruk380/anaconda3/envs/Reinforcement_Learning_YT_course/lib/python3.8/site-packages/stable_baselines3/common/evaluation.py:65: UserWarning: Evaluation environment is not wrapped with a ``Monitor`` wrapper. This may result in reporting modified episode lengths and rewards, if other wrappers happen to modify these. Consider wrapping environment first with ``Monitor`` wrapper.
#   warnings.warn(

# %% [markdown]
# # 9. Changing Policies

# %%
net_arch = [dict(pi=[128,128,128,128], vf=[128,128,128,128])]
# new neural network hase 128 units in each 4 layers (custom actor)
# same for value focntion (vf)

# %% [markdown]
# Netword Arch
#     This is an example of specifying a different architecture for the different neural networks used in PPO
# You can also simplify this and use:
#     new_arch = [128,128] to use the same for both

# %%
model = PPO('MlpPolicy',env,verbose=1,tensorboard_log=log_path,policy_kwargs={'net_arch':net_arch})
# Out:
# Using cpu device

# %%
model.learn(total_timesteps=20000,callback=eval_callback)
# Out:
# Logging to Training/Logs/PPO_5
# -----------------------------
# | time/              |      |
# |    fps             | 1919 |
# |    iterations      | 1    |
# |    time_elapsed    | 1    |
# |    total_timesteps | 2048 |
# -----------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1347        |
# |    iterations           | 2           |
# |    time_elapsed         | 3           |
# |    total_timesteps      | 4096        |
# | train/                  |             |
# |    approx_kl            | 0.014819702 |
# |    clip_fraction        | 0.211       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.682      |
# |    explained_variance   | -0.0103     |
# |    learning_rate        | 0.0003      |
# |    loss                 | 2.98        |
# |    n_updates            | 10          |
# |    policy_gradient_loss | -0.0227     |
# |    value_loss           | 22.1        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1211        |
# |    iterations           | 3           |
# |    time_elapsed         | 5           |
# |    total_timesteps      | 6144        |
# | train/                  |             |
# |    approx_kl            | 0.016252838 |
# |    clip_fraction        | 0.192       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.646      |
# |    explained_variance   | 0.434       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 9.8         |
# |    n_updates            | 20          |
# |    policy_gradient_loss | -0.031      |
# |    value_loss           | 26.5        |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 1136         |
# |    iterations           | 4            |
# |    time_elapsed         | 7            |
# |    total_timesteps      | 8192         |
# | train/                  |              |
# |    approx_kl            | 0.0136537105 |
# |    clip_fraction        | 0.146        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.603       |
# |    explained_variance   | 0.369        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 18.2         |
# |    n_updates            | 30           |
# |    policy_gradient_loss | -0.0259      |
# |    value_loss           | 43.9         |
# ------------------------------------------
# Eval num_timesteps=10000, episode_reward=200.00 +/- 0.00
# Episode length: 200.00 +/- 0.00
# ------------------------------------------
# | eval/                   |              |
# |    mean_ep_length       | 200          |
# |    mean_reward          | 200          |
# | time/                   |              |
# |    total timesteps      | 10000        |
# | train/                  |              |
# |    approx_kl            | 0.0081908405 |
# |    clip_fraction        | 0.0792       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.579       |
# |    explained_variance   | 0.489        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 15.9         |
# |    n_updates            | 40           |
# |    policy_gradient_loss | -0.0137      |
# |    value_loss           | 42.7         |
# ------------------------------------------
# ------------------------------
# | time/              |       |
# |    fps             | 1073  |
# |    iterations      | 5     |
# |    time_elapsed    | 9     |
# |    total_timesteps | 10240 |
# ------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1073        |
# |    iterations           | 6           |
# |    time_elapsed         | 11          |
# |    total_timesteps      | 12288       |
# | train/                  |             |
# |    approx_kl            | 0.007783146 |
# |    clip_fraction        | 0.0929      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.544      |
# |    explained_variance   | 0.58        |
# |    learning_rate        | 0.0003      |
# |    loss                 | 5.07        |
# |    n_updates            | 50          |
# |    policy_gradient_loss | -0.00975    |
# |    value_loss           | 43.2        |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 1065         |
# |    iterations           | 7            |
# |    time_elapsed         | 13           |
# |    total_timesteps      | 14336        |
# | train/                  |              |
# |    approx_kl            | 0.0066615064 |
# |    clip_fraction        | 0.0602       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.534       |
# |    explained_variance   | 0.571        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 9.65         |
# |    n_updates            | 60           |
# |    policy_gradient_loss | -0.00631     |
# |    value_loss           | 56.6         |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 1065         |
# |    iterations           | 8            |
# |    time_elapsed         | 15           |
# |    total_timesteps      | 16384        |
# | train/                  |              |
# |    approx_kl            | 0.0030488118 |
# |    clip_fraction        | 0.0688       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.538       |
# |    explained_variance   | 0.634        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 10.3         |
# |    n_updates            | 70           |
# |    policy_gradient_loss | -0.00515     |
# |    value_loss           | 43.6         |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1063        |
# |    iterations           | 9           |
# |    time_elapsed         | 17          |
# |    total_timesteps      | 18432       |
# | train/                  |             |
# |    approx_kl            | 0.002648149 |
# |    clip_fraction        | 0.0177      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.533      |
# |    explained_variance   | 0.348       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 25.7        |
# |    n_updates            | 80          |
# |    policy_gradient_loss | -0.00126    |
# |    value_loss           | 77.9        |
# -----------------------------------------
# Eval num_timesteps=20000, episode_reward=200.00 +/- 0.00
# Episode length: 200.00 +/- 0.00
# -----------------------------------------
# | eval/                   |             |
# |    mean_ep_length       | 200         |
# |    mean_reward          | 200         |
# | time/                   |             |
# |    total timesteps      | 20000       |
# | train/                  |             |
# |    approx_kl            | 0.004845647 |
# |    clip_fraction        | 0.0377      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.551      |
# |    explained_variance   | 0.499       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 41.8        |
# |    n_updates            | 90          |
# |    policy_gradient_loss | -0.00177    |
# |    value_loss           | 95.5        |
# -----------------------------------------
# ------------------------------
# | time/              |       |
# |    fps             | 1038  |
# |    iterations      | 10    |
# |    time_elapsed    | 19    |
# |    total_timesteps | 20480 |
# ------------------------------
# /home/uruk380/anaconda3/envs/Reinforcement_Learning_YT_course/lib/python3.8/site-packages/stable_baselines3/common/evaluation.py:65: UserWarning: Evaluation environment is not wrapped with a ``Monitor`` wrapper. This may result in reporting modified episode lengths and rewards, if other wrappers happen to modify these. Consider wrapping environment first with ``Monitor`` wrapper.
#   warnings.warn(

# %% [markdown]
# # 10. Using an Alternative Algorithm

# %%
from stable_baselines3 import DQN
# Out:
# Using cpu device

# %%
model = DQN('MlpPolicy', env, verbose=1,tensorboard_log=log_path)
# Out:
# Using cpu device

# %%
model.learn(total_timesteps=20000)
# Out:
# Logging to Training/Logs/DQN_1
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.967    |
# | time/               |          |
# |    episodes         | 4        |
# |    fps              | 8310     |
# |    time_elapsed     | 0        |
# |    total timesteps  | 69       |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.915    |
# | time/               |          |
# |    episodes         | 8        |
# |    fps              | 10525    |
# |    time_elapsed     | 0        |
# |    total timesteps  | 179      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.861    |
# | time/               |          |
# |    episodes         | 12       |
# |    fps              | 10892    |
# |    time_elapsed     | 0        |
# |    total timesteps  | 292      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.808    |
# | time/               |          |
# |    episodes         | 16       |
# |    fps              | 11222    |
# |    time_elapsed     | 0        |
# |    total timesteps  | 404      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.762    |
# | time/               |          |
# |    episodes         | 20       |
# |    fps              | 10657    |
# |    time_elapsed     | 0        |
# |    total timesteps  | 501      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.706    |
# | time/               |          |
# |    episodes         | 24       |
# |    fps              | 11050    |
# |    time_elapsed     | 0        |
# |    total timesteps  | 618      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.677    |
# | time/               |          |
# |    episodes         | 28       |
# |    fps              | 10719    |
# |    time_elapsed     | 0        |
# |    total timesteps  | 681      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.629    |
# | time/               |          |
# |    episodes         | 32       |
# |    fps              | 10271    |
# |    time_elapsed     | 0        |
# |    total timesteps  | 781      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.597    |
# | time/               |          |
# |    episodes         | 36       |
# |    fps              | 9887     |
# |    time_elapsed     | 0        |
# |    total timesteps  | 849      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.534    |
# | time/               |          |
# |    episodes         | 40       |
# |    fps              | 9848     |
# |    time_elapsed     | 0        |
# |    total timesteps  | 981      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.467    |
# | time/               |          |
# |    episodes         | 44       |
# |    fps              | 9924     |
# |    time_elapsed     | 0        |
# |    total timesteps  | 1122     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.421    |
# | time/               |          |
# |    episodes         | 48       |
# |    fps              | 10161    |
# |    time_elapsed     | 0        |
# |    total timesteps  | 1219     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.387    |
# | time/               |          |
# |    episodes         | 52       |
# |    fps              | 10195    |
# |    time_elapsed     | 0        |
# |    total timesteps  | 1290     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.341    |
# | time/               |          |
# |    episodes         | 56       |
# |    fps              | 10376    |
# |    time_elapsed     | 0        |
# |    total timesteps  | 1387     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.294    |
# | time/               |          |
# |    episodes         | 60       |
# |    fps              | 10517    |
# |    time_elapsed     | 0        |
# |    total timesteps  | 1487     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.238    |
# | time/               |          |
# |    episodes         | 64       |
# |    fps              | 10740    |
# |    time_elapsed     | 0        |
# |    total timesteps  | 1605     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.188    |
# | time/               |          |
# |    episodes         | 68       |
# |    fps              | 10933    |
# |    time_elapsed     | 0        |
# |    total timesteps  | 1710     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.14     |
# | time/               |          |
# |    episodes         | 72       |
# |    fps              | 11069    |
# |    time_elapsed     | 0        |
# |    total timesteps  | 1810     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.0828   |
# | time/               |          |
# |    episodes         | 76       |
# |    fps              | 11260    |
# |    time_elapsed     | 0        |
# |    total timesteps  | 1931     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 80       |
# |    fps              | 11358    |
# |    time_elapsed     | 0        |
# |    total timesteps  | 2042     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 84       |
# |    fps              | 11452    |
# |    time_elapsed     | 0        |
# |    total timesteps  | 2131     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 88       |
# |    fps              | 11458    |
# |    time_elapsed     | 0        |
# |    total timesteps  | 2215     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 92       |
# |    fps              | 11483    |
# |    time_elapsed     | 0        |
# |    total timesteps  | 2296     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 96       |
# |    fps              | 11555    |
# |    time_elapsed     | 0        |
# |    total timesteps  | 2382     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 100      |
# |    fps              | 11590    |
# |    time_elapsed     | 0        |
# |    total timesteps  | 2484     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 104      |
# |    fps              | 11668    |
# |    time_elapsed     | 0        |
# |    total timesteps  | 2582     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 108      |
# |    fps              | 11706    |
# |    time_elapsed     | 0        |
# |    total timesteps  | 2685     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 112      |
# |    fps              | 11605    |
# |    time_elapsed     | 0        |
# |    total timesteps  | 2773     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 116      |
# |    fps              | 11500    |
# |    time_elapsed     | 0        |
# |    total timesteps  | 2829     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 120      |
# |    fps              | 11499    |
# |    time_elapsed     | 0        |
# |    total timesteps  | 2902     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 124      |
# |    fps              | 11540    |
# |    time_elapsed     | 0        |
# |    total timesteps  | 3002     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 128      |
# |    fps              | 11633    |
# |    time_elapsed     | 0        |
# |    total timesteps  | 3123     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 132      |
# |    fps              | 11663    |
# |    time_elapsed     | 0        |
# |    total timesteps  | 3184     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 136      |
# |    fps              | 11685    |
# |    time_elapsed     | 0        |
# |    total timesteps  | 3251     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 140      |
# |    fps              | 11778    |
# |    time_elapsed     | 0        |
# |    total timesteps  | 3371     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 144      |
# |    fps              | 11807    |
# |    time_elapsed     | 0        |
# |    total timesteps  | 3443     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 148      |
# |    fps              | 11854    |
# |    time_elapsed     | 0        |
# |    total timesteps  | 3527     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 152      |
# |    fps              | 11930    |
# |    time_elapsed     | 0        |
# |    total timesteps  | 3630     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 156      |
# |    fps              | 11964    |
# |    time_elapsed     | 0        |
# |    total timesteps  | 3718     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 160      |
# |    fps              | 11991    |
# |    time_elapsed     | 0        |
# |    total timesteps  | 3795     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 164      |
# |    fps              | 12035    |
# |    time_elapsed     | 0        |
# |    total timesteps  | 3875     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 168      |
# |    fps              | 12043    |
# |    time_elapsed     | 0        |
# |    total timesteps  | 3954     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 172      |
# |    fps              | 12060    |
# |    time_elapsed     | 0        |
# |    total timesteps  | 4010     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 176      |
# |    fps              | 12152    |
# |    time_elapsed     | 0        |
# |    total timesteps  | 4170     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 180      |
# |    fps              | 12205    |
# |    time_elapsed     | 0        |
# |    total timesteps  | 4277     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 184      |
# |    fps              | 12270    |
# |    time_elapsed     | 0        |
# |    total timesteps  | 4392     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 188      |
# |    fps              | 12273    |
# |    time_elapsed     | 0        |
# |    total timesteps  | 4497     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 192      |
# |    fps              | 12313    |
# |    time_elapsed     | 0        |
# |    total timesteps  | 4579     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 196      |
# |    fps              | 12338    |
# |    time_elapsed     | 0        |
# |    total timesteps  | 4676     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 200      |
# |    fps              | 12405    |
# |    time_elapsed     | 0        |
# |    total timesteps  | 4816     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 204      |
# |    fps              | 12456    |
# |    time_elapsed     | 0        |
# |    total timesteps  | 4950     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 208      |
# |    fps              | 12485    |
# |    time_elapsed     | 0        |
# |    total timesteps  | 5034     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 212      |
# |    fps              | 12503    |
# |    time_elapsed     | 0        |
# |    total timesteps  | 5123     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 216      |
# |    fps              | 12526    |
# |    time_elapsed     | 0        |
# |    total timesteps  | 5202     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 220      |
# |    fps              | 12547    |
# |    time_elapsed     | 0        |
# |    total timesteps  | 5261     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 224      |
# |    fps              | 12574    |
# |    time_elapsed     | 0        |
# |    total timesteps  | 5350     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 228      |
# |    fps              | 12620    |
# |    time_elapsed     | 0        |
# |    total timesteps  | 5455     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 232      |
# |    fps              | 12624    |
# |    time_elapsed     | 0        |
# |    total timesteps  | 5513     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 236      |
# |    fps              | 12616    |
# |    time_elapsed     | 0        |
# |    total timesteps  | 5572     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 240      |
# |    fps              | 12654    |
# |    time_elapsed     | 0        |
# |    total timesteps  | 5723     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 244      |
# |    fps              | 12672    |
# |    time_elapsed     | 0        |
# |    total timesteps  | 5833     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 248      |
# |    fps              | 12694    |
# |    time_elapsed     | 0        |
# |    total timesteps  | 5943     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 252      |
# |    fps              | 12715    |
# |    time_elapsed     | 0        |
# |    total timesteps  | 6042     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 256      |
# |    fps              | 12724    |
# |    time_elapsed     | 0        |
# |    total timesteps  | 6138     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 260      |
# |    fps              | 12733    |
# |    time_elapsed     | 0        |
# |    total timesteps  | 6292     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 264      |
# |    fps              | 12767    |
# |    time_elapsed     | 0        |
# |    total timesteps  | 6383     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 268      |
# |    fps              | 12786    |
# |    time_elapsed     | 0        |
# |    total timesteps  | 6464     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 272      |
# |    fps              | 12806    |
# |    time_elapsed     | 0        |
# |    total timesteps  | 6579     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 276      |
# |    fps              | 12834    |
# |    time_elapsed     | 0        |
# |    total timesteps  | 6678     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 280      |
# |    fps              | 12885    |
# |    time_elapsed     | 0        |
# |    total timesteps  | 6836     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 284      |
# |    fps              | 12898    |
# |    time_elapsed     | 0        |
# |    total timesteps  | 6915     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 288      |
# |    fps              | 12912    |
# |    time_elapsed     | 0        |
# |    total timesteps  | 6989     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 292      |
# |    fps              | 12902    |
# |    time_elapsed     | 0        |
# |    total timesteps  | 7052     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 296      |
# |    fps              | 12910    |
# |    time_elapsed     | 0        |
# |    total timesteps  | 7117     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 300      |
# |    fps              | 12932    |
# |    time_elapsed     | 0        |
# |    total timesteps  | 7190     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 304      |
# |    fps              | 12941    |
# |    time_elapsed     | 0        |
# |    total timesteps  | 7275     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 308      |
# |    fps              | 12940    |
# |    time_elapsed     | 0        |
# |    total timesteps  | 7325     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 312      |
# |    fps              | 12965    |
# |    time_elapsed     | 0        |
# |    total timesteps  | 7407     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 316      |
# |    fps              | 12958    |
# |    time_elapsed     | 0        |
# |    total timesteps  | 7464     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 320      |
# |    fps              | 12976    |
# |    time_elapsed     | 0        |
# |    total timesteps  | 7572     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 324      |
# |    fps              | 12992    |
# |    time_elapsed     | 0        |
# |    total timesteps  | 7678     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 328      |
# |    fps              | 13000    |
# |    time_elapsed     | 0        |
# |    total timesteps  | 7746     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 332      |
# |    fps              | 13012    |
# |    time_elapsed     | 0        |
# |    total timesteps  | 7820     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 336      |
# |    fps              | 13027    |
# |    time_elapsed     | 0        |
# |    total timesteps  | 7904     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 340      |
# |    fps              | 13029    |
# |    time_elapsed     | 0        |
# |    total timesteps  | 7995     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 344      |
# |    fps              | 13044    |
# |    time_elapsed     | 0        |
# |    total timesteps  | 8073     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 348      |
# |    fps              | 13053    |
# |    time_elapsed     | 0        |
# |    total timesteps  | 8151     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 352      |
# |    fps              | 13059    |
# |    time_elapsed     | 0        |
# |    total timesteps  | 8220     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 356      |
# |    fps              | 13064    |
# |    time_elapsed     | 0        |
# |    total timesteps  | 8290     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 360      |
# |    fps              | 13075    |
# |    time_elapsed     | 0        |
# |    total timesteps  | 8358     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 364      |
# |    fps              | 13067    |
# |    time_elapsed     | 0        |
# |    total timesteps  | 8432     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 368      |
# |    fps              | 13080    |
# |    time_elapsed     | 0        |
# |    total timesteps  | 8511     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 372      |
# |    fps              | 13091    |
# |    time_elapsed     | 0        |
# |    total timesteps  | 8573     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 376      |
# |    fps              | 13109    |
# |    time_elapsed     | 0        |
# |    total timesteps  | 8667     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 380      |
# |    fps              | 13117    |
# |    time_elapsed     | 0        |
# |    total timesteps  | 8744     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 384      |
# |    fps              | 13138    |
# |    time_elapsed     | 0        |
# |    total timesteps  | 8827     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 388      |
# |    fps              | 13143    |
# |    time_elapsed     | 0        |
# |    total timesteps  | 8903     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 392      |
# |    fps              | 13156    |
# |    time_elapsed     | 0        |
# |    total timesteps  | 9008     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 396      |
# |    fps              | 13146    |
# |    time_elapsed     | 0        |
# |    total timesteps  | 9093     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 400      |
# |    fps              | 13146    |
# |    time_elapsed     | 0        |
# |    total timesteps  | 9176     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 404      |
# |    fps              | 13152    |
# |    time_elapsed     | 0        |
# |    total timesteps  | 9284     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 408      |
# |    fps              | 13155    |
# |    time_elapsed     | 0        |
# |    total timesteps  | 9386     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 412      |
# |    fps              | 13168    |
# |    time_elapsed     | 0        |
# |    total timesteps  | 9479     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 416      |
# |    fps              | 13169    |
# |    time_elapsed     | 0        |
# |    total timesteps  | 9541     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 420      |
# |    fps              | 13171    |
# |    time_elapsed     | 0        |
# |    total timesteps  | 9628     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 424      |
# |    fps              | 13181    |
# |    time_elapsed     | 0        |
# |    total timesteps  | 9717     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 428      |
# |    fps              | 13173    |
# |    time_elapsed     | 0        |
# |    total timesteps  | 9799     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 432      |
# |    fps              | 13178    |
# |    time_elapsed     | 0        |
# |    total timesteps  | 9874     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 436      |
# |    fps              | 13203    |
# |    time_elapsed     | 0        |
# |    total timesteps  | 9976     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 440      |
# |    fps              | 13139    |
# |    time_elapsed     | 0        |
# |    total timesteps  | 10046    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 444      |
# |    fps              | 13144    |
# |    time_elapsed     | 0        |
# |    total timesteps  | 10118    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 448      |
# |    fps              | 13142    |
# |    time_elapsed     | 0        |
# |    total timesteps  | 10190    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 452      |
# |    fps              | 13149    |
# |    time_elapsed     | 0        |
# |    total timesteps  | 10279    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 456      |
# |    fps              | 13158    |
# |    time_elapsed     | 0        |
# |    total timesteps  | 10382    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 460      |
# |    fps              | 13161    |
# |    time_elapsed     | 0        |
# |    total timesteps  | 10476    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 464      |
# |    fps              | 13159    |
# |    time_elapsed     | 0        |
# |    total timesteps  | 10557    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 468      |
# |    fps              | 13159    |
# |    time_elapsed     | 0        |
# |    total timesteps  | 10631    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 472      |
# |    fps              | 13156    |
# |    time_elapsed     | 0        |
# |    total timesteps  | 10709    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 476      |
# |    fps              | 13158    |
# |    time_elapsed     | 0        |
# |    total timesteps  | 10782    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 480      |
# |    fps              | 13159    |
# |    time_elapsed     | 0        |
# |    total timesteps  | 10876    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 484      |
# |    fps              | 13177    |
# |    time_elapsed     | 0        |
# |    total timesteps  | 11007    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 488      |
# |    fps              | 13175    |
# |    time_elapsed     | 0        |
# |    total timesteps  | 11068    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 492      |
# |    fps              | 13171    |
# |    time_elapsed     | 0        |
# |    total timesteps  | 11137    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 496      |
# |    fps              | 13172    |
# |    time_elapsed     | 0        |
# |    total timesteps  | 11202    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 500      |
# |    fps              | 13190    |
# |    time_elapsed     | 0        |
# |    total timesteps  | 11288    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 504      |
# |    fps              | 13204    |
# |    time_elapsed     | 0        |
# |    total timesteps  | 11379    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 508      |
# |    fps              | 13204    |
# |    time_elapsed     | 0        |
# |    total timesteps  | 11473    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 512      |
# |    fps              | 13204    |
# |    time_elapsed     | 0        |
# |    total timesteps  | 11552    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 516      |
# |    fps              | 13202    |
# |    time_elapsed     | 0        |
# |    total timesteps  | 11617    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 520      |
# |    fps              | 13214    |
# |    time_elapsed     | 0        |
# |    total timesteps  | 11694    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 524      |
# |    fps              | 13222    |
# |    time_elapsed     | 0        |
# |    total timesteps  | 11769    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 528      |
# |    fps              | 13225    |
# |    time_elapsed     | 0        |
# |    total timesteps  | 11860    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 532      |
# |    fps              | 13230    |
# |    time_elapsed     | 0        |
# |    total timesteps  | 11937    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 536      |
# |    fps              | 13230    |
# |    time_elapsed     | 0        |
# |    total timesteps  | 11998    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 540      |
# |    fps              | 13243    |
# |    time_elapsed     | 0        |
# |    total timesteps  | 12126    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 544      |
# |    fps              | 13239    |
# |    time_elapsed     | 0        |
# |    total timesteps  | 12176    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 548      |
# |    fps              | 13243    |
# |    time_elapsed     | 0        |
# |    total timesteps  | 12248    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 552      |
# |    fps              | 13237    |
# |    time_elapsed     | 0        |
# |    total timesteps  | 12309    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 556      |
# |    fps              | 13234    |
# |    time_elapsed     | 0        |
# |    total timesteps  | 12369    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 560      |
# |    fps              | 13242    |
# |    time_elapsed     | 0        |
# |    total timesteps  | 12454    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 564      |
# |    fps              | 13229    |
# |    time_elapsed     | 0        |
# |    total timesteps  | 12530    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 568      |
# |    fps              | 13258    |
# |    time_elapsed     | 0        |
# |    total timesteps  | 12658    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 572      |
# |    fps              | 13212    |
# |    time_elapsed     | 0        |
# |    total timesteps  | 12768    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 576      |
# |    fps              | 13162    |
# |    time_elapsed     | 0        |
# |    total timesteps  | 12855    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 580      |
# |    fps              | 13118    |
# |    time_elapsed     | 0        |
# |    total timesteps  | 12979    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 584      |
# |    fps              | 13075    |
# |    time_elapsed     | 0        |
# |    total timesteps  | 13054    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 588      |
# |    fps              | 13048    |
# |    time_elapsed     | 1        |
# |    total timesteps  | 13131    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 592      |
# |    fps              | 13040    |
# |    time_elapsed     | 1        |
# |    total timesteps  | 13200    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 596      |
# |    fps              | 13035    |
# |    time_elapsed     | 1        |
# |    total timesteps  | 13306    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 600      |
# |    fps              | 13056    |
# |    time_elapsed     | 1        |
# |    total timesteps  | 13463    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 604      |
# |    fps              | 13061    |
# |    time_elapsed     | 1        |
# |    total timesteps  | 13535    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 608      |
# |    fps              | 13063    |
# |    time_elapsed     | 1        |
# |    total timesteps  | 13605    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# ...
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 708      |
# |    fps              | 13132    |
# |    time_elapsed     | 1        |
# |    total timesteps  | 15555    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 712      |
# |    fps              | 13137    |
# |    time_elapsed     | 1        |
# |    total timesteps  | 15636    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 716      |
# |    fps              | 13143    |
# |    time_elapsed     | 1        |
# |    total timesteps  | 15749    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 720      |
# |    fps              | 13146    |
# |    time_elapsed     | 1        |
# |    total timesteps  | 15835    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 724      |
# |    fps              | 13138    |
# |    time_elapsed     | 1        |
# |    total timesteps  | 15898    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 728      |
# |    fps              | 13142    |
# |    time_elapsed     | 1        |
# |    total timesteps  | 15999    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 732      |
# |    fps              | 13146    |
# |    time_elapsed     | 1        |
# |    total timesteps  | 16114    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 736      |
# |    fps              | 13158    |
# |    time_elapsed     | 1        |
# |    total timesteps  | 16208    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 740      |
# |    fps              | 13161    |
# |    time_elapsed     | 1        |
# |    total timesteps  | 16281    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 744      |
# |    fps              | 13158    |
# |    time_elapsed     | 1        |
# |    total timesteps  | 16354    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 748      |
# |    fps              | 13156    |
# |    time_elapsed     | 1        |
# |    total timesteps  | 16417    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 752      |
# |    fps              | 13170    |
# |    time_elapsed     | 1        |
# |    total timesteps  | 16567    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 756      |
# |    fps              | 13175    |
# |    time_elapsed     | 1        |
# |    total timesteps  | 16645    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 760      |
# |    fps              | 13178    |
# |    time_elapsed     | 1        |
# |    total timesteps  | 16704    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 764      |
# |    fps              | 13182    |
# |    time_elapsed     | 1        |
# |    total timesteps  | 16769    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 768      |
# |    fps              | 13180    |
# |    time_elapsed     | 1        |
# |    total timesteps  | 16863    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 772      |
# |    fps              | 13187    |
# |    time_elapsed     | 1        |
# |    total timesteps  | 16947    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 776      |
# |    fps              | 13197    |
# |    time_elapsed     | 1        |
# |    total timesteps  | 17077    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 780      |
# |    fps              | 13203    |
# |    time_elapsed     | 1        |
# |    total timesteps  | 17161    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 784      |
# |    fps              | 13207    |
# |    time_elapsed     | 1        |
# |    total timesteps  | 17217    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 788      |
# |    fps              | 13217    |
# |    time_elapsed     | 1        |
# |    total timesteps  | 17354    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 792      |
# |    fps              | 13232    |
# |    time_elapsed     | 1        |
# |    total timesteps  | 17476    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 796      |
# |    fps              | 13223    |
# |    time_elapsed     | 1        |
# |    total timesteps  | 17534    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 800      |
# |    fps              | 13239    |
# |    time_elapsed     | 1        |
# |    total timesteps  | 17647    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 804      |
# |    fps              | 13242    |
# |    time_elapsed     | 1        |
# |    total timesteps  | 17724    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 808      |
# |    fps              | 13244    |
# |    time_elapsed     | 1        |
# |    total timesteps  | 17820    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 812      |
# |    fps              | 13260    |
# |    time_elapsed     | 1        |
# |    total timesteps  | 17938    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 816      |
# |    fps              | 13265    |
# |    time_elapsed     | 1        |
# |    total timesteps  | 18025    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 820      |
# |    fps              | 13245    |
# |    time_elapsed     | 1        |
# |    total timesteps  | 18095    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 824      |
# |    fps              | 13254    |
# |    time_elapsed     | 1        |
# |    total timesteps  | 18186    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 828      |
# |    fps              | 13252    |
# |    time_elapsed     | 1        |
# |    total timesteps  | 18239    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 832      |
# |    fps              | 13254    |
# |    time_elapsed     | 1        |
# |    total timesteps  | 18314    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 836      |
# |    fps              | 13263    |
# |    time_elapsed     | 1        |
# |    total timesteps  | 18433    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 840      |
# |    fps              | 13263    |
# |    time_elapsed     | 1        |
# |    total timesteps  | 18521    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 844      |
# |    fps              | 13268    |
# |    time_elapsed     | 1        |
# |    total timesteps  | 18609    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 848      |
# |    fps              | 13266    |
# |    time_elapsed     | 1        |
# |    total timesteps  | 18678    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 852      |
# |    fps              | 13280    |
# |    time_elapsed     | 1        |
# |    total timesteps  | 18831    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 856      |
# |    fps              | 13282    |
# |    time_elapsed     | 1        |
# |    total timesteps  | 18896    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 860      |
# |    fps              | 13282    |
# |    time_elapsed     | 1        |
# |    total timesteps  | 18994    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 864      |
# |    fps              | 13281    |
# |    time_elapsed     | 1        |
# |    total timesteps  | 19043    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 868      |
# |    fps              | 13285    |
# |    time_elapsed     | 1        |
# |    total timesteps  | 19098    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 872      |
# |    fps              | 13287    |
# |    time_elapsed     | 1        |
# |    total timesteps  | 19181    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 876      |
# |    fps              | 13289    |
# |    time_elapsed     | 1        |
# |    total timesteps  | 19263    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 880      |
# |    fps              | 13306    |
# |    time_elapsed     | 1        |
# |    total timesteps  | 19391    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 884      |
# |    fps              | 13308    |
# |    time_elapsed     | 1        |
# |    total timesteps  | 19461    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 888      |
# |    fps              | 13311    |
# |    time_elapsed     | 1        |
# |    total timesteps  | 19561    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 892      |
# |    fps              | 13318    |
# |    time_elapsed     | 1        |
# |    total timesteps  | 19684    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 896      |
# |    fps              | 13322    |
# |    time_elapsed     | 1        |
# |    total timesteps  | 19762    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 900      |
# |    fps              | 13324    |
# |    time_elapsed     | 1        |
# |    total timesteps  | 19829    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 904      |
# |    fps              | 13326    |
# |    time_elapsed     | 1        |
# |    total timesteps  | 19911    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 908      |
# |    fps              | 13333    |
# |    time_elapsed     | 1        |
# |    total timesteps  | 19991    |
# ----------------------------------
